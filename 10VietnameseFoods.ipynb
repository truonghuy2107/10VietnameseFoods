# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
folder= '/content/drive/MyDrive/10VietnameseFoods/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder + 'BanhMi.'+ str(i) +'.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()
folder = '/content/drive/MyDrive/10VietnameseFoods/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('BanhMi'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BanhXeo'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BunBoHue'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BunCha'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BunThitNuong'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('ChaoLong'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('ComTam'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('GoiCuon'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('MiQuang'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('Pho'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
    
 
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('10foods_photos.npy', photos)
save('10foods_labels.npy', labels)

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200,200, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(photos, labels, batch_size=64,epochs=20, verbose=1)
model.save('10foods.h5')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (500, 200, 200, 3) (500,)
# Epoch 1/20
# 8/8 [==============================] - 2s 167ms/step - loss: 1144.4679 - accuracy: 0.1000
# Epoch 2/20
# 8/8 [==============================] - 1s 157ms/step - loss: 29.5813 - accuracy: 0.0980
# Epoch 3/20
# 8/8 [==============================] - 1s 157ms/step - loss: 2.2638 - accuracy: 0.1540
# Epoch 4/20
# 8/8 [==============================] - 1s 158ms/step - loss: 2.1258 - accuracy: 0.2520
# Epoch 5/20
# 8/8 [==============================] - 1s 157ms/step - loss: 1.7843 - accuracy: 0.4040
# Epoch 6/20
# 8/8 [==============================] - 1s 156ms/step - loss: 1.1827 - accuracy: 0.6480
# Epoch 7/20
# 8/8 [==============================] - 1s 159ms/step - loss: 0.7340 - accuracy: 0.7980
# Epoch 8/20
# 8/8 [==============================] - 1s 157ms/step - loss: 0.3182 - accuracy: 0.9060
# Epoch 9/20
# 8/8 [==============================] - 1s 156ms/step - loss: 0.2089 - accuracy: 0.9460
# Epoch 10/20
# 8/8 [==============================] - 1s 157ms/step - loss: 0.1559 - accuracy: 0.9640
# Epoch 11/20
# 8/8 [==============================] - 1s 157ms/step - loss: 0.0600 - accuracy: 0.9820
# Epoch 12/20
# 8/8 [==============================] - 1s 156ms/step - loss: 0.0184 - accuracy: 0.9980
# Epoch 13/20
# 8/8 [==============================] - 1s 156ms/step - loss: 0.0076 - accuracy: 0.9980
# Epoch 14/20
# 8/8 [==============================] - 1s 158ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 15/20
# 8/8 [==============================] - 1s 166ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 16/20
# 8/8 [==============================] - 1s 165ms/step - loss: 6.8772e-04 - accuracy: 1.0000
# Epoch 17/20
# 8/8 [==============================] - 1s 165ms/step - loss: 3.8650e-04 - accuracy: 1.0000
# Epoch 18/20
# 8/8 [==============================] - 1s 155ms/step - loss: 2.5652e-04 - accuracy: 1.0000
# Epoch 19/20
# 8/8 [==============================] - 1s 157ms/step - loss: 1.9408e-04 - accuracy: 1.0000
# Epoch 20/20
# 8/8 [==============================] - 1s 156ms/step - loss: 1.5583e-04 - accuracy: 1.0000

# %%
classes = ["BanhMi","BanhXeo","BunBoHue","BunCha","BunThitNuong","ChaoLong","ComTam","GoiCuon","MiQuang","Pho"]
img = load_img('/content/drive/MyDrive/10VietnameseFoods/BanhMi.8.jpg', target_size=(200,200))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.10451094 0.10071089 0.09955011 0.09845889 0.10294875 0.10430484
#   0.09983197 0.10020278 0.09203429 0.09744646]]
# 'BanhMi'

# %%
classes = ["BanhMi","BanhXeo","BunBoHue","BunCha","BunThitNuong","ChaoLong","ComTam","GoiCuon","MiQuang","Pho"]
img = load_img('test.jpg', target_size=(200,200))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255

y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.09298932 0.09817053 0.09419672 0.09556759 0.1022163  0.1009352
#   0.10639285 0.10547135 0.09559213 0.10846807]]
# 'Pho'

# %%
from keras.preprocessing.image   import load_img
from keras.preprocessing.image  import img_to_array
from keras.models               import load_model
import numpy as np
import matplotlib.pyplot as plt

img = load_img('test.jpg', target_size=(200, 200))
img = img_to_array(img)
img = img.reshape(1, 200, 200, 3)
img = img.astype('float32')
img = img / 255.0

# load model
model = load_model('10foods.h5')
# predict the class
result = model.predict(img)
print('Giá trị dự đoán:', np.argmax(result))
plt.show()
# Out:
# Giá trị dự đoán: 9
